# %%
# %matplotlib notebook

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
Updated_2017 = "reduced_updated_2017.csv"

updated_17_pd = pd.read_csv(Updated_2017)
updated_17_pd.head()
# Out:
#    Unnamed: 0 What is your gender?  What is your age?  \
# 0           0               Female               27.0
# 1           1                 male               31.0
# 2           2                 male               36.0
# 3           3                 Male               22.0
# 4           4               female               52.0
#
#                     Country  \
# 0            United Kingdom
# 1            United Kingdom
# 2  United States of America
# 3  United States of America
# 4  United States of America
#
#   What US state or territory do you <strong>live</strong> in?  \
# 0                                                NaN
# 1                                                NaN
# 2                                           Missouri
# 3                                         Washington
# 4                                           Illinois
#
#            What is your race?  \
# 0                         NaN
# 1                         NaN
# ...

# %%
#updated_17_pd.plot.bar(x='age_bins',y='Age_Int')

# %%
filter_country_age = updated_17_pd.filter(["Country", "Age_Int"]) 
filter_country_age
# Out:
#                       Country  Age_Int
# 0              United Kingdom     20.0
# 1              United Kingdom     30.0
# 2    United States of America     30.0
# 3    United States of America     20.0
# 4    United States of America     50.0
# ..                        ...      ...
# 751            United Kingdom     40.0
# 752  United States of America     40.0
# 753                       NaN      NaN
# 754  United States of America     30.0
# 755                       NaN      NaN
#
# [756 rows x 2 columns]

# %%
filter_after = filter_country_age[(filter_country_age['Country'] == "United States of America") | (filter_country_age['Country'] == "United Kingdom") | (filter_country_age['Country'] == "Canada")]
filter_after
# Out:
#                       Country  Age_Int
# 0              United Kingdom     20.0
# 1              United Kingdom     30.0
# 2    United States of America     30.0
# 3    United States of America     20.0
# 4    United States of America     50.0
# ..                        ...      ...
# 749  United States of America     20.0
# 750  United States of America     30.0
# 751            United Kingdom     40.0
# 752  United States of America     40.0
# 754  United States of America     30.0
#
# [589 rows x 2 columns]

# %%
country_count = updated_17_pd['Country'].value_counts()
country_count
# Out:
# United States of America    497
# United Kingdom               66
# Canada                       26
# Germany                      22
# France                       17
# Spain                        15
# Netherlands                  14
# India                        13
# Australia                    12
# Switzerland                   6
# Ireland                       4
# New Zealand                   4
# Romania                       4
# Japan                         3
# Argentina                     3
# Sweden                        3
# Mexico                        3
# Belgium                       3
# South Africa                  3
# Russia                        3
# Portugal                      2
# Greece                        2
# Brazil                        2
# Pakistan                      2
# Czech Republic                2
# Ukraine                       2
# Bulgaria                      2
# Indonesia                     2
# Hungary                       2
# ...

# %%
top_three_countries = country_count.loc[['United States of America','United Kingdom', 'Canada']]
top_three_countries
# Out:
# United States of America    497
# United Kingdom               66
# Canada                       26
# Name: Country, dtype: int64

# %%
filter_after.groupby(['Age_Int','Country']).size().unstack().plot(kind='bar',stacked=True)
#plt.xlim(-0.25)
#plt.ylim(0, max(Country)+0.4
plt.title("Top Three Countries Age Bracket Totals")
plt.ylim(-0.25)
plt.xlabel("Age Brackets", fontsize=10)
plt.ylabel("Totals", fontsize=10)
plt.tight_layout()
plt.grid()
plt.show()
plt.savefig("Images/2017_Age_Totals_By_Top_Three_Countries.png")
# Out:
# <img src="data:image/png;base64,..." width="639.999974568686">
